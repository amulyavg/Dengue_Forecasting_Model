# %% [markdown]
# <a href="https://colab.research.google.com/github/sreejairagavarapu/Research/blob/code-as-of-3%2F13%2F2024/PCA_(code_uses_dataset_not_including_standing_water).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.linalg import eigh
import numpy as np

df = pd.read_csv('/content/compiledwithoutstandingwater.csv')

df = df.fillna(data.mean())



features = ['Precipitation', 'Humidity', 'Temperature', 'Average of Economic growth: the rate of change of real GDP', 'Average of Gross Domestic Product, billions of U.S. dollars', 'Average of GDP per capita, current U.S. dollars', 'Average of Household consumption, billion USD', 'Average of Unemployment rate', 'Average of Government spending, billion USD', 'Average of Government debt as percent of GDP', 'Average of Foreign aid and official development assistance received', 'Average of Government effectiveness index (-2.5 weak; 2.5 strong)', 'Average of Control of corruption (-2.5 weak; 2.5 strong)', 'Average of Political stability index (-2.5 weak; 2.5 strong)', 'Average of Internet users, percent of population', 'Average of Mobile phone subscribers, in millions', 'Average of Carbon dioxide emissions per capita', 'Average of Greenhouse gas emissions', 'Average of Forest area, percent of total land area', 'Average of Innovations index (0-100)', 'Average of Population density, people per square km', 'Average of Health spending per capita',	'Average of Health spending as percent of GDP',	'Average of Prevalence of undernourishment, percent of population',	'Average of Gini income inequality index', 'Average of Poverty ratio, percent living on less than 1.90 USD a day',	'Average of Poverty ratio, percent living on less than 5.50 USD a day',	'Average of Public spending on education, percent of GDP',	'Average of Literacy rate',	'Average of Globalization index (0-100)',	'Average of Economic globalization index (0-100)',	'Average of Political globalization index (0-100)',	'Average of Social globalization index (0-100)',	'Average of Tourist arrivals',	'Average of Percent of world tourist arrivals',	'Average of Human Development Index (0 - 1)',	'Average of Economic freedom, overall index (0-100)',	'Average of Population size, in millions', 'Average of Percent urban population',	'Average of Rural population, percent of total population',	'Average of Population growth, percent',	'Average of Fragile state index, 0 (low) - 120 (high)',	'Average of Economic decline index, 0 (low) - 10 (high)']
x = df.loc[:, features].values

# Separating out the target
y = df.loc[:,['Dengue']].values

# Standardizing the features
x = StandardScaler().fit_transform(x)


# Perform PCA
pca = PCA(n_components=15)  # You can adjust the number of components as needed
principal_components = pca.fit_transform(x)

principalDf = pd.DataFrame(data = principal_components
             , columns = ['principal component 1', 'principal component 2', 'principal component 3', 'principal component 4', 'principal component 5', 'principal component 6', 'principal component 7', 'principal component 8', 'principal component 9', 'principal component 10', 'principal component 11', 'principal component 12', 'principal component 13', 'principal component 14', 'principal component 15'])


finalDf = pd.concat([principalDf, df[['Dengue']]], axis = 1)
explained_variance_ratio = pca.explained_variance_ratio_



# Plot scree plot
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='-')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Scree Plot')
plt.grid(True)
plt.show()

# Plot Explained Variance Ratio
explained_var_ratio = pca.explained_variance_ratio_
cumulative_var_ratio = np.cumsum(explained_var_ratio)

plt.plot(range(1, len(cumulative_var_ratio) + 1), cumulative_var_ratio, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Explained Variance Ratio vs. Number of Principal Components')
plt.show()

# Display the DataFrame of principal components
#print("Principal Components DataFrame:")
#print(principalDf)

#sns.pairplot(finalDf, hue='Dengue', vars=['principal component 1', 'principal component 2', 'principal component 3', 'principal component 4', 'principal component 5', 'principal component 6', 'principal component 7', 'principal component 8', 'principal component 9', 'principal component 10', 'principal component 11', 'principal component 12', 'principal component 13', 'principal component 14', 'principal component 15'])
#plt.show()


pd.set_option('display.max_rows', None)
principalDf.head(120)
# Out:
# <ipython-input-19-dff634b47523>:12: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = df.fillna(data.mean())
#      principal component 1  principal component 2  principal component 3  \
# 0                 7.809959               0.341134              -0.990675
# 1                 7.820723               0.365171              -0.950942
# 2                 7.803872               0.374809              -0.949504
# 3                 7.800668               0.397868              -0.901544
# 4                 7.766920               0.418372              -0.875267
# 5                 7.701973               0.372950              -0.970047
# 6                 7.608470               0.279968              -1.120639
# ...

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.linalg import eigh
import numpy as np

# Example Data
df = pd.read_csv('/content/NotFinal3.csv')

data = df.fillna(df.mean())


# Step 1: Standardize the Data
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Step 2-5: PCA
pca = PCA()
X_pca = pca.fit_transform(X_std)

# Plot Explained Variance Ratio
explained_var_ratio = pca.explained_variance_ratio_
cumulative_var_ratio = np.cumsum(explained_var_ratio)

plt.plot(range(1, len(cumulative_var_ratio) + 1), cumulative_var_ratio, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Explained Variance Ratio vs. Number of Principal Components')
plt.show()
# Out:
# <ipython-input-5-5b195e0d885e>:17: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data = df.fillna(df.mean())
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5b195e0d885e> in <cell line: 22>()
#      20 # Step 1: Standardize the Data
#      21 scaler = StandardScaler()
# ---> 22 X_std = scaler.fit_transform(X)
#      23
#      24 # Step 2-5: PCA
#
# NameError: name 'X' is not defined
